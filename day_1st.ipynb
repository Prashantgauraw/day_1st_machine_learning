# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashantgauraw/day_1st_machine_learning/blob/main/day_1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-7caf7e29-a373-40b4-b3d2-383794bd46c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7caf7e29-a373-40b4-b3d2-383794bd46c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("homeprices.csv")
x=df.area
y=df.price
plt.title('area vs home price')
plt.scatter(df.area,df.price)
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()

print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#drop the price of home
import pandas as pd
from sklearn.linear_model import LinearRegression
df = pd.read_csv("homeprices.csv")
#drop the price column
new_df = df.drop('price', axis = 'columns')
print(df)
print()
print(new_df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
#
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
#Loading the data set
import pandas as pd
from sklearn.linear_model import LinearRegression
df = pd.read_csv("homeprices.csv")
new_df = df.drop('price', axis = 'columns')
print(new_df.values)
print()
print(df.price.values)
# Out:
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]
#
# [550000 565000 610000 680000 725000]

# %%
#Predict price of a home with area = 3300 sqr ft

import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv("homeprices.csv")
new_df = df.drop('price', axis='columns')
#creating the model
reg = LinearRegression()
reg.fit(new_df.values, df.price.values)
# Making Predictions
print(reg.predict([[3300]]))
# Out:
# [628715.75342466]
